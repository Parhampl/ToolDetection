# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.8/677.8 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
model = YOLO('/content/best60epochTool.pt')
# Out:
# /content

# %%
import glob
from IPython.display import Image, display
import cv2
from PIL import Image
# %cd {HOME}


# Open an image
img = cv2.imread('/content/top-view-mechanical-tools-arrangement.jpg')


# Convert RGB to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


results = model.predict(source='/content/top-view-mechanical-tools-arrangement.jpg', save=True, conf=0.3)
# cv2_imshow(results)

for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
print('number of Tools in Image',len(result.boxes))
# Out:
# /content
#
# image 1/1 /content/top-view-mechanical-tools-arrangement.jpg: 448x640 7 Plierss, 4 Regular Wrenchs, 2 Screwdrivers, 4 washers, 461.6ms
# Speed: 7.2ms preprocess, 461.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# number of Tools in Image 17
